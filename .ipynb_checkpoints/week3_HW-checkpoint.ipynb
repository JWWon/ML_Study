# %% [markdown]
# ## Load pandas

# %%
import pandas as pd
df = pd.read_csv('binary.csv')

# %%
x = df.iloc[:, :3] # x : admit, gre, gpa
y = df.iloc[:, 3] # y : rank

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = \
    train_test_split(x, y, test_size = 0.3, random_state = 33)
# train_x, train_y => 테스트할 데이터 랜덤으로 선택

# %% [markdown]
# ## Load preprocessing

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler().fit(train_x)
scaled_train_x = scaler.transform(train_x)
scaled_test_x = scaler.transform(test_x)
scaled_test_x
# Out:
# array([[-0.69954392,  0.97298495,  0.14796432],
#        [-0.69954392, -0.77004631, -1.02963287],
#        [-0.69954392, -0.24713693,  0.25501861],
#        [-0.69954392,  0.97298495,  1.16498008],
#        [-0.69954392,  0.45007557,  1.61996081],
#        [-0.69954392,  0.45007557,  1.43261581],
#        [-0.69954392, -0.59574318, -1.85930362],
#        [-0.69954392, -0.59574318, -1.24374145],
#        [-0.69954392,  0.97298495,  1.61996081],
#        [-0.69954392,  1.84450057, -0.22672569],
#        [-0.69954392, -0.77004631, -1.56490432],
#        [-0.69954392, -1.11865256, -0.86905144],
#        [-0.69954392, -0.42144006, -0.94934215],
#        [-0.69954392,  0.97298495, -0.33377998],
#        [-0.69954392, -0.77004631, -0.97610573],
#        [-0.69954392,  0.27577244,  0.49589077],
#        [-0.69954392,  0.45007557, -0.60141571],
#        [-0.69954392, -0.77004631, -0.44083427],
#        [-0.69954392, -1.29295568, -1.69872219],
#        [-0.69954392,  0.45007557,  0.33530933],
#        [ 1.4295028 , -1.64156193, -0.65494285],
#        [ 1.4295028 , -0.77004631, -0.70847   ],
#        [-0.69954392, -1.81586506,  0.57618148],
#        [ 1.4295028 ,  0.27577244, -0.06614426],
#        [-0.69954392,  1.3215912 , -0.22672569],
#        [-0.69954392,  0.45007557,  1.2452708 ],
#        [-0.69954392, -0.59574318, -2.0734122 ],
#        [-0.69954392,  0.97298495,  1.61996081],
#        [-0.69954392, -0.77004631, -1.10992359],
#        [-0.69954392, -0.59574318, -0.78876072],
#        [-0.69954392, -0.07283381,  1.08468936],
#        [ 1.4295028 , -0.94434943, -2.0734122 ],
#        [-0.69954392, -0.59574318, -0.73523357],
#        [-0.69954392,  0.10146932,  1.32556152],
#        [ 1.4295028 ,  0.27577244,  0.14796432],
#        [-0.69954392,  1.14728807,  1.19174365],
#        [-0.69954392, -1.11865256,  0.49589077],
#        [ 1.4295028 ,  0.10146932, -0.65494285],
#        [ 1.4295028 , -0.59574318,  1.11145294],
#        [ 1.4295028 ,  1.49589432, -1.05639644],
#        [ 1.4295028 ,  0.27577244,  1.61996081],
#        [-0.69954392,  0.62437869,  0.52265434],
#        [-0.69954392,  1.84450057,  0.20149147],
#        [-0.69954392, -0.59574318,  0.30854576],
#        [ 1.4295028 , -0.42144006, -0.60141571],
#        [-0.69954392,  0.62437869, -0.86905144],
#        [-0.69954392,  0.62437869,  1.61996081],
#        [-0.69954392,  0.27577244, -1.45785003],
#        [-0.69954392, -0.59574318, -1.45785003],
#        [-0.69954392, -1.99016818, -0.68170643],
#        [-0.69954392, -0.07283381, -0.09290783],
#        [-0.69954392, -0.77004631,  1.29879794],
#        [-0.69954392, -0.24713693, -0.94934215],
#        [ 1.4295028 ,  0.62437869,  1.61996081],
#        [-0.69954392,  0.62437869, -0.19996212],
#        [-0.69954392, -1.11865256, -1.40432289],
#        [ 1.4295028 ,  0.10146932,  0.20149147],
#        [-0.69954392, -0.07283381,  1.61996081],
#        [-0.69954392, -0.07283381,  0.30854576],
#        [-0.69954392,  0.10146932,  0.52265434],
#        [ 1.4295028 ,  1.84450057,  0.09443718],
#        [-0.69954392, -1.11865256,  0.12120075],
#        [-0.69954392,  0.79868182, -0.76199714],
#        [-0.69954392, -1.46725881, -1.88606719],
#        [ 1.4295028 , -0.59574318,  1.61996081],
#        [ 1.4295028 ,  0.62437869,  0.73676292],
#        [-0.69954392, -1.29295568, -1.10992359],
#        [-0.69954392, -0.07283381,  0.01414646],
#        [ 1.4295028 ,  0.27577244,  1.48614295],
#        [-0.69954392, -1.11865256, -1.24374145],
#        [ 1.4295028 , -0.42144006, -0.01261711],
#        [-0.69954392,  1.84450057,  0.38883648],
#        [-0.69954392, -1.46725881, -1.16345073],
#        [ 1.4295028 ,  1.84450057, -0.92257858],
#        [-0.69954392, -3.21029006, -1.51137718],
#        [-0.69954392, -0.07283381,  1.61996081],
#        [ 1.4295028 ,  0.10146932,  1.32556152],
#        [-0.69954392,  1.84450057,  1.5396701 ],
#        [-0.69954392, -0.42144006, -0.52112499],
#        [-0.69954392,  0.79868182,  0.81705364],
#        [ 1.4295028 ,  0.27577244,  0.84381721],
#        [-0.69954392,  1.14728807,  1.45937938],
#        [-0.69954392,  1.84450057, -0.65494285],
#        [-0.69954392, -1.64156193, -0.92257858],
#        [ 1.4295028 ,  0.79868182, -1.05639644],
#        [-0.69954392, -0.07283381,  0.1747279 ],
#        [-0.69954392, -0.42144006, -0.30701641],
#        [ 1.4295028 ,  0.10146932, -1.10992359],
#        [-0.69954392,  0.62437869,  0.25501861],
#        [-0.69954392, -1.99016818, -2.23399364],
#        [-0.69954392,  0.45007557,  0.73676292],
#        [ 1.4295028 , -1.11865256,  0.6564722 ],
#        [-0.69954392, -0.94434943, -0.01261711],
#        [-0.69954392, -0.94434943, -1.64519504],
#        [-0.69954392,  0.97298495,  0.33530933],
#        [ 1.4295028 , -0.94434943,  0.49589077],
#        [-0.69954392, -0.07283381,  0.46912719],
#        [ 1.4295028 ,  1.84450057,  0.3620729 ],
#        [-0.69954392, -1.81586506, -0.14643498],
#        [-0.69954392,  0.27577244, -0.46759785],
#        [ 1.4295028 ,  0.27577244,  0.9508715 ],
#        [-0.69954392,  0.27577244, -0.86905144],
#        [ 1.4295028 ,  1.67019745,  1.08468936],
#        [-0.69954392, -2.16447131, -1.27050502],
#        [-0.69954392, -1.29295568, -0.4140707 ],
#        [-0.69954392,  0.62437869, -0.17319855],
#        [ 1.4295028 , -0.07283381, -1.43108646],
#        [ 1.4295028 , -0.59574318,  0.68323577],
#        [-0.69954392, -0.77004631,  0.3620729 ],
#        [-0.69954392, -0.94434943,  0.12120075],
#        [ 1.4295028 ,  0.45007557,  1.48614295],
#        [ 1.4295028 ,  0.45007557,  0.62970863],
#        [-0.69954392,  0.79868182, -0.84228786],
#        [-0.69954392,  1.84450057,  0.89734435],
#        [ 1.4295028 ,  0.62437869, -0.68170643],
#        [ 1.4295028 , -0.42144006,  1.19174365],
#        [-0.69954392,  0.62437869,  0.73676292],
#        [ 1.4295028 ,  0.79868182, -2.60868365],
#        [ 1.4295028 ,  1.84450057,  1.61996081],
#        [-0.69954392, -0.24713693, -0.54788856]])

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(fit_intercept = True, max_iter = 1000)
model.fit(scaled_train_x, train_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
model.coef_
model.intercept_
# Out:
# array([-1.9008825 , -0.49352873, -0.83076719, -1.54926394])

# %%
model.score(scaled_test_x, test_y)
# Out:
# 0.38333333333333336
